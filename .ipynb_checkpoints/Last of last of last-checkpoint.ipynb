# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/cs-training.csv', index_col = 0)
df
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                      1                              0.766127   45
# 2                      0                              0.957151   40
# 3                      0                              0.658180   38
# 4                      0                              0.233810   30
# 5                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149996                 0                              0.040674   74
# 149997                 0                              0.299745   44
# 149998                 0                              0.246044   58
# 149999                 0                              0.000000   30
# 150000                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 1                                          2     0.802982         9120.0
# 2                                          0     0.121876         2600.0
# 3                                          1     0.085113         3042.0
# 4                                          0     0.036050         3300.0
# 5                                          1     0.024926        63588.0
# ...                                      ...          ...            ...
# 149996                                     0     0.225131         2100.0
# 149997                                     0     0.716562         5584.0
# 149998                                     0  3870.000000            NaN
# 149999                                     0     0.000000         5716.0
# 150000                                     0     0.249908         8158.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                                    13                        0
# 2                                     4                        0
# 3                                     2                        1
# 4                                     5                        0
# 5                                     7                        0
# ...                                 ...                      ...
# 149996                                4                        0
# 149997                                4                        0
# 149998                               18                        0
# 149999                                4                        0
# 150000                                8                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                                  6                                     0
# 2                                  0                                     0
# 3                                  0                                     0
# 4                                  0                                     0
# 5                                  1                                     0
# ...                              ...                                   ...
# 149996                             1                                     0
# 149997                             1                                     0
# 149998                             1                                     0
# 149999                             0                                     0
# 150000                             2                                     0
#
#         NumberOfDependents
# 1                      2.0
# 2                      1.0
# 3                      0.0
# 4                      0.0
# 5                      0.0
# ...                    ...
# 149996                 0.0
# 149997                 2.0
# 149998                 0.0
# 149999                 0.0
# 150000                 0.0
#
# [150000 rows x 11 columns]

# %% [markdown]
# # 컬럼값 단순화

# %%
df.columns = ['more90_2yrs', 'rev_util', 'age', 'num_30-59_due', 'debt_ratio', 'month_income', 'num_cre_loan', 'num_90late', 'num_REL', 'num_60-89_due', 'num_dependents']
df
# Out:
#         more90_2yrs  rev_util  age  num_30-59_due   debt_ratio  month_income  \
# 1                 1  0.766127   45              2     0.802982        9120.0
# 2                 0  0.957151   40              0     0.121876        2600.0
# 3                 0  0.658180   38              1     0.085113        3042.0
# 4                 0  0.233810   30              0     0.036050        3300.0
# 5                 0  0.907239   49              1     0.024926       63588.0
# ...             ...       ...  ...            ...          ...           ...
# 149996            0  0.040674   74              0     0.225131        2100.0
# 149997            0  0.299745   44              0     0.716562        5584.0
# 149998            0  0.246044   58              0  3870.000000           NaN
# 149999            0  0.000000   30              0     0.000000        5716.0
# 150000            0  0.850283   64              0     0.249908        8158.0
#
#         num_cre_loan  num_90late  num_REL  num_60-89_due  num_dependents
# 1                 13           0        6              0             2.0
# 2                  4           0        0              0             1.0
# 3                  2           1        0              0             0.0
# 4                  5           0        0              0             0.0
# 5                  7           0        1              0             0.0
# ...              ...         ...      ...            ...             ...
# 149996             4           0        1              0             0.0
# 149997             4           0        1              0             2.0
# 149998            18           0        1              0             0.0
# 149999             4           0        0              0             0.0
# 150000             8           0        2              0             0.0
#
# [150000 rows x 11 columns]

# %% [markdown]
# # nan 값 처리 - 평균값으로 대체

# %%
df.isna().sum()
# Out:
# more90_2yrs           0
# rev_util              0
# age                   0
# num_30-59_due         0
# debt_ratio            0
# month_income      29731
# num_cre_loan          0
# num_90late            0
# num_REL               0
# num_60-89_due         0
# num_dependents     3924
# dtype: int64

# %%
df.fillna(df.mean(), inplace = True)

# %%
df.isna().sum()
# Out:
# more90_2yrs       0
# rev_util          0
# age               0
# num_30-59_due     0
# debt_ratio        0
# month_income      0
# num_cre_loan      0
# num_90late        0
# num_REL           0
# num_60-89_due     0
# num_dependents    0
# dtype: int64

# %% [markdown]
# # rev_util 이상치 수정

# %%
# 현재 가용 자금 관련

# %%
df[df['rev_util']>1] = 0

# %%
df['rev_util'].value_counts()
# Out:
# 0.000000    14199
# 1.000000    10256
# 1.000000       17
# 0.950100        8
# 0.954092        6
#             ...
# 0.355181        1
# 0.217510        1
# 0.185457        1
# 0.054679        1
# 0.373187        1
# Name: rev_util, Length: 122595, dtype: int64

# %%
df
# Out:
#         more90_2yrs  rev_util  age  num_30-59_due   debt_ratio  month_income  \
# 1                 1  0.766127   45              2     0.802982   9120.000000
# 2                 0  0.957151   40              0     0.121876   2600.000000
# 3                 0  0.658180   38              1     0.085113   3042.000000
# 4                 0  0.233810   30              0     0.036050   3300.000000
# 5                 0  0.907239   49              1     0.024926  63588.000000
# ...             ...       ...  ...            ...          ...           ...
# 149996            0  0.040674   74              0     0.225131   2100.000000
# 149997            0  0.299745   44              0     0.716562   5584.000000
# 149998            0  0.246044   58              0  3870.000000   6670.221237
# 149999            0  0.000000   30              0     0.000000   5716.000000
# 150000            0  0.850283   64              0     0.249908   8158.000000
#
#         num_cre_loan  num_90late  num_REL  num_60-89_due  num_dependents
# 1                 13           0        6              0             2.0
# 2                  4           0        0              0             1.0
# 3                  2           1        0              0             0.0
# 4                  5           0        0              0             0.0
# 5                  7           0        1              0             0.0
# ...              ...         ...      ...            ...             ...
# 149996             4           0        1              0             0.0
# 149997             4           0        1              0             2.0
# 149998            18           0        1              0             0.0
# 149999             4           0        0              0             0.0
# 150000             8           0        2              0             0.0
#
# [150000 rows x 11 columns]

# %%
df['debt_ratio'].value_counts()
# Out:
# 0.000000    7434
# 1.000000     227
# 4.000000     173
# 2.000000     170
# 3.000000     162
#             ...
# 0.541576       1
# 0.289780       1
# 0.334490       1
# 0.246783       1
# 0.722570       1
# Name: debt_ratio, Length: 111727, dtype: int64

# %%
df.mean()
# Out:
# more90_2yrs          0.058593
# rev_util             0.297056
# age                 51.319820
# num_30-59_due        0.398533
# debt_ratio         347.577024
# month_income      6548.066216
# num_cre_loan         8.311647
# num_90late           0.251853
# num_REL              1.003140
# num_60-89_due        0.230813
# num_dependents       0.736968
# dtype: float64

# %%
# 수입이 없는데 현재 운용 가능한 자금이 지나치게 많은 이상치를 0으로 대체
df.loc[(df.month_income == 0) & (df.debt_ratio > 1), 'debt_ratio'] = 0

# %%
df['debt_ratio'].value_counts()
# Out:
# 0.000000    8931
# 1.000000     227
# 2.000000     164
# 4.000000     162
# 3.000000     157
#             ...
# 0.309049       1
# 0.005270       1
# 0.145202       1
# 0.435404       1
# 0.486089       1
# Name: debt_ratio, Length: 111643, dtype: int64

# %%
df
# Out:
#         more90_2yrs  rev_util  age  num_30-59_due   debt_ratio  month_income  \
# 1                 1  0.766127   45              2     0.802982   9120.000000
# 2                 0  0.957151   40              0     0.121876   2600.000000
# 3                 0  0.658180   38              1     0.085113   3042.000000
# 4                 0  0.233810   30              0     0.036050   3300.000000
# 5                 0  0.907239   49              1     0.024926  63588.000000
# ...             ...       ...  ...            ...          ...           ...
# 149996            0  0.040674   74              0     0.225131   2100.000000
# 149997            0  0.299745   44              0     0.716562   5584.000000
# 149998            0  0.246044   58              0  3870.000000   6670.221237
# 149999            0  0.000000   30              0     0.000000   5716.000000
# 150000            0  0.850283   64              0     0.249908   8158.000000
#
#         num_cre_loan  num_90late  num_REL  num_60-89_due  num_dependents
# 1                 13           0        6              0             2.0
# 2                  4           0        0              0             1.0
# 3                  2           1        0              0             0.0
# 4                  5           0        0              0             0.0
# 5                  7           0        1              0             0.0
# ...              ...         ...      ...            ...             ...
# 149996             4           0        1              0             0.0
# 149997             4           0        1              0             2.0
# 149998            18           0        1              0             0.0
# 149999             4           0        0              0             0.0
# 150000             8           0        2              0             0.0
#
# [150000 rows x 11 columns]

# %%
df[df['num_dependents']>df.num_dependents.mean()]
# Out:
#         more90_2yrs  rev_util  age  num_30-59_due   debt_ratio  month_income  \
# 1                 1  0.766127   45              2     0.802982   9120.000000
# 2                 0  0.957151   40              0     0.121876   2600.000000
# 6                 0  0.213179   74              0     0.375607   3500.000000
# 9                 0  0.116951   27              0    46.000000   6670.221237
# 10                0  0.189169   57              0     0.606291  23684.000000
# ...             ...       ...  ...            ...          ...           ...
# 149987            0  0.168102   49              0     0.080384   5000.000000
# 149990            0  0.013356   62              0     0.001408   9233.000000
# 149991            0  0.055518   46              0     0.609779   4335.000000
# 149993            0  0.871976   50              0  4132.000000   6670.221237
# 149997            0  0.299745   44              0     0.716562   5584.000000
#
#         num_cre_loan  num_90late  num_REL  num_60-89_due  num_dependents
# 1                 13           0        6              0        2.000000
# 2                  4           0        0              0        1.000000
# 6                  3           0        1              0        1.000000
# 9                  2           0        0              0        0.757222
# 10                 9           0        4              0        2.000000
# ...              ...         ...      ...            ...             ...
# 149987            16           0        0              0        1.000000
# 149990             4           0        0              0        3.000000
# 149991             7           0        1              0        2.000000
# 149993            11           0        1              0        3.000000
# 149997             4           0        1              0        2.000000
#
# [61495 rows x 11 columns]

# %% [markdown]
# # num_dependents 이상치 수정 - 평균값

# %%
sns.boxplot(x = "num_dependents", orient = "v", data = df)
plt.show()

# %%
# 평균값보다 지나치게 높은 outlier들은 평균값으로 대체
df.loc[df.num_dependents > df.num_dependents.mean(), 'num_dependents'] = df.num_dependents.mean()

# %%
df.more90_2yrs.value_counts()
# Out:
# 0    141211
# 1      8789
# Name: more90_2yrs, dtype: int64

# %% [markdown]
# # num_cre_loan 이상치 평균값으로 대체

# %%
sns.boxplot(x = "num_cre_loan", orient = "v", data = df)
plt.show()

# %%
df[df['num_cre_loan']>20]
# Out:
#         more90_2yrs  rev_util  age  num_30-59_due   debt_ratio  month_income  \
# 27                0  0.052436   58              0     0.097672        8333.0
# 45                0  0.368876   68              0  1687.500000           1.0
# 50                0  0.000080   70              0     0.256340        6900.0
# 112               0  0.318446   58              0     1.382629        3833.0
# 129               0  0.151913   36              0     0.266394       12000.0
# ...             ...       ...  ...            ...          ...           ...
# 149721            0  0.046757   64              0     0.679064        5000.0
# 149724            0  0.535406   53              1     0.458885        4000.0
# 149735            0  0.111259   49              1     0.370277        5133.0
# 149840            0  0.011694   51              0     0.010800       37500.0
# 149917            0  0.253137   50              3     0.503715        9554.0
#
#         num_cre_loan  num_90late  num_REL  num_60-89_due  num_dependents
# 27                22           0        1              0        0.000000
# 45                31           0        1              0        0.000000
# 50                21           1        1              0        0.000000
# 112               26           0        4              0        0.000000
# 129               22           0        2              0        0.000000
# ...              ...         ...      ...            ...             ...
# 149721            24           0        1              0        0.000000
# 149724            25           0        3              0        0.736968
# 149735            23           0        1              0        0.736968
# 149840            48           0        0              0        0.000000
# 149917            27           0        2              0        0.736968
#
# [3953 rows x 11 columns]

# %%
df.mean()
# Out:
# more90_2yrs          0.058593
# rev_util             0.297056
# age                 51.319820
# num_30-59_due        0.398533
# debt_ratio         330.667391
# month_income      6548.066216
# num_cre_loan         8.311647
# num_90late           0.251853
# num_REL              1.003140
# num_60-89_due        0.230813
# num_dependents       0.302132
# dtype: float64

# %%
df.loc[df.num_cre_loan > df.num_cre_loan.mean(), 'num_cre_loan'] = df.num_cre_loan.mean()

# %%
df.mean()
# Out:
# more90_2yrs          0.058593
# rev_util             0.297056
# age                 51.319820
# num_30-59_due        0.398533
# debt_ratio         330.667391
# month_income      6548.066216
# num_cre_loan         6.297162
# num_90late           0.251853
# num_REL              1.003140
# num_60-89_due        0.230813
# num_dependents       0.302132
# dtype: float64

# %% [markdown]
# # 데이터셋 나누기

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns = ['more90_2yrs'])
y = df.more90_2yrs
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y)

# %% [markdown]
# # 학습

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200, max_depth=6, max_features=10)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=10, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # 예측

# %%
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score, classification_report, roc_auc_score
rf_pred_proba_train = rf.predict_proba(X_train)
rf_pred_proba_test = rf.predict_proba(X_test)

# %% [markdown]
# # 평가

# %%
def print_metrics(y, pred, title = None):
    acc = accuracy_score(y,pred)
    recall = recall_score(y,pred)
    precision = precision_score(y,pred)
    f1 = f1_score(y,pred)
    
    if title:
        print('title')
    print(f'정확도:{acc}, 재현율:{recall}, 정밀도:{precision}, f1:{f1}')

# %%
rf_train_pred = rf.predict(X_train)
rf_test_pred = rf.predict(X_test)

# %%
print_metrics(y_train, rf_train_pred, "RF-Train")
# Out:
# title
# 정확도:0.94576, 재현율:0.15807038834951456, 정밀도:0.6537013801756587, f1:0.2545809919374542

# %%
print_metrics(y_test, rf_test_pred, "RF-Train")
# Out:
# title
# 정확도:0.9435733333333334, 재현율:0.14201183431952663, 정밀도:0.574585635359116, f1:0.2277372262773723

# %%
rf_train_score = roc_auc_score(y_train, rf_pred_proba_train[:, 1])
rf_test_score = roc_auc_score(y_test, rf_pred_proba_test[:, 1])
print('RandomForest Roc Score - train : {}, test - {}'.format(rf_train_score, rf_test_score))
# Out:
# RandomForest Roc Score - train : 0.8546411747020036, test - 0.8503620796777067

# %% [markdown]
# # 적당한 max_depth 찾기

# %%
depth_list = range(1, 11)

# %%
train_acc_list = []
test_acc_list = []

# %%
for depth in depth_list:
    rf = RandomForestClassifier(max_depth = depth)
    rf.fit(X_train, y_train)
    
    pred_train = rf.predict(X_train)
    pred_test = rf.predict(X_test)
    
    acc_train = accuracy_score(y_train, pred_train)
    acc_test = accuracy_score(y_test, pred_test)
    
    train_acc_list.append(acc_train)
    test_acc_list.append(acc_test)
# Out:
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\amelie\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
train_acc_list
# Out:
# [0.9414044444444445,
#  0.9414044444444445,
#  0.9414044444444445,
#  0.94328,
#  0.9436711111111111,
#  0.9450488888888889,
#  0.9457333333333333,
#  0.9467822222222222,
#  0.9487911111111111,
#  0.9512533333333333]

# %%
test_acc_list
# Out:
# [0.9414133333333333,
#  0.9414133333333333,
#  0.9414133333333333,
#  0.94344,
#  0.9435466666666666,
#  0.94376,
#  0.9430933333333333,
#  0.94352,
#  0.9430133333333334,
#  0.94296]

# %%
import pandas as pd
df_1 = pd.DataFrame({'Train': train_acc_list, 'Test': test_acc_list}, 
                  index = depth_list)
df_1
# Out:
#        Train      Test
# 1   0.941404  0.941413
# 2   0.941404  0.941413
# 3   0.941404  0.941413
# 4   0.943280  0.943440
# 5   0.943671  0.943547
# 6   0.945049  0.943760
# 7   0.945733  0.943093
# 8   0.946782  0.943520
# 9   0.948791  0.943013
# 10  0.951253  0.942960

# %%
df_1.plot(figsize = (7, 7));

# %% [markdown]
# # max depth 수정

# %%
rf = RandomForestClassifier(n_estimators=200, max_depth=6, max_features=10)
rf.fit(X_train, y_train)

rf_pred_proba_train = rf.predict_proba(X_train)
rf_pred_proba_test = rf.predict_proba(X_test)

rf_train_score = roc_auc_score(y_train, rf_pred_proba_train[:, 1])
rf_test_score = roc_auc_score(y_test, rf_pred_proba_test[:, 1])
print('RandomForest Roc Score - train : {}, test - {}'.format(rf_train_score, rf_test_score))
